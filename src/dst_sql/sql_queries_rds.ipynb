# %%
import pandas as pd
import numpy as np
import pymysql
import sys
import static

# %% [markdown]
# les différentes tables à requêter :
#
# ATTENTION : après chaque requête et avant d'en faire une nouvelle, il faut bien penser a fermer la connexion avec la bdd (sinon, ça ba buguer)
#
# - aircraft
# - flights_metrics
# - flights_summary
# - countries
# - airports
# - cities

# %%
# pour faire des requêtes sql

# connexion à la BDD

name_database = static.name_bdd
cnx = pymysql.connect(host = static.host, user = static.user, password = static.password)
cursor = cnx.cursor()
use_db = "use {name}".format(name = name_database)
cursor.execute(use_db)

#### Execute query ####

query1 = ("select * from COUNTRIES")
cursor.execute(query1)




#### Create dataframe from resultant table ####
frame = pd.DataFrame(cursor.fetchall())


# TJRS FERMER LA CONNEXION APR7S UNE REQUETE (SINON : Bug) !

cursor.close()
cnx.close()


frame
# Out:
#       0    1                     2
# 0    AD  AND               Andorra
# 1    AE  ARE  United Arab Emirates
# 2    AF  AFG           Afghanistan
# 3    AG  ATG   Antigua and Barbuda
# 4    AI  AIA              Anguilla
# ..   ..  ...                   ...
# 248  YE  YEM                 Yemen
# 249  YT  MYT               Mayotte
# 250  ZA  ZAF          South Africa
# 251  ZM  ZMB                Zambia
# 252  ZW  ZWE              Zimbabwe
#
# [253 rows x 3 columns]

# %%
# pour faire des requêtes sql

# connexion à la BDD

name_database = static.name_bdd
cnx = pymysql.connect(host = static.host, user = static.user, password = static.password)
cursor = cnx.cursor()
use_db = "use {name}".format(name = name_database)
cursor.execute(use_db)


# test jointure entre toutes les tables

#### Execute query ####

query1 = ("(SELECT * from FLIGHTS_SUMMARY LEFT JOIN AIRCRAFT ON FLIGHTS_SUMMARY.hex = AIRCRAFT.hex LEFT JOIN FLIGHTS_METRICS ON AIRCRAFT.hex = FLIGHTS_METRICS.hex LEFT JOIN AIRPORTS a ON FLIGHTS_SUMMARY.dep_iata = a.iata_code  LEFT JOIN AIRPORTS b ON FLIGHTS_SUMMARY.arr_iata = b.iata_code LEFT JOIN COUNTRIES as c ON a.country_code = c.code LEFT JOIN COUNTRIES as d ON b.country_code = d.code)")
cursor.execute(query1)


#### Create dataframe from resultant table ####
frame = pd.DataFrame(cursor.fetchall())
pd.set_option("display.max_rows", None, "display.max_columns", None)

# TJRS FERMER LA CONNEXION APR7S UNE REQUETE (SINON : Bug) !

cursor.close()
cnx.close()


frame.head()
# Out:
#    0       1        2       3              4   5    6    7           8   \
# 0   1  300738  DLH1656  LH1656  To be defined  DE  MUC  TSR  1900-01-01
# 1   1  300738  DLH1656  LH1656  To be defined  DE  MUC  TSR  1900-01-01
# 2   1  300738  DLH1656  LH1656  To be defined  DE  MUC  TSR  1900-01-01
# 3   1  300738  DLH1656  LH1656  To be defined  DE  MUC  TSR  1900-01-01
# 4   1  300738  DLH1656  LH1656  To be defined  DE  MUC  TSR  1900-01-01
#
#            9               10              11          12          13  \
# 0  1900-01-01 0 days 00:01:00 0 days 00:01:00  1900-01-01  1900-01-01
# 1  1900-01-01 0 days 00:01:00 0 days 00:01:00  1900-01-01  1900-01-01
# 2  1900-01-01 0 days 00:01:00 0 days 00:01:00  1900-01-01  1900-01-01
# 3  1900-01-01 0 days 00:01:00 0 days 00:01:00  1900-01-01  1900-01-01
# 4  1900-01-01 0 days 00:01:00 0 days 00:01:00  1900-01-01  1900-01-01
#
#                14              15          16              17           18  \
# 0 0 days 00:01:00 0 days 00:01:00  2022-08-16 0 days 15:36:00  no terminal
# 1 0 days 00:01:00 0 days 00:01:00  2022-08-16 0 days 15:36:00  no terminal
# 2 0 days 00:01:00 0 days 00:01:00  2022-08-16 0 days 15:36:00  no terminal
# 3 0 days 00:01:00 0 days 00:01:00  2022-08-16 0 days 15:36:00  no terminal
# 4 0 days 00:01:00 0 days 00:01:00  2022-08-16 0 days 15:36:00  no terminal
#
#             19             20             21      22   23  24    25   26  \
# 0  no terminal  To be defined  To be defined  300738  DLH  LH  E195  E95
# 1  no terminal  To be defined  To be defined  300738  DLH  LH  E195  E95
# 2  no terminal  To be defined  To be defined  300738  DLH  LH  E195  E95
# 3  no terminal  To be defined  To be defined  300738  DLH  LH  E195  E95
# 4  no terminal  To be defined  To be defined  300738  DLH  LH  E195  E95
#
#         27    28      29       30      31       32        33       34     35  \
# 0  EMBRAER     1  300738  DLH1656  LH1656  47.1026  17.91910  10210.0  109.0
# 1  EMBRAER   118  300738  DLH1656  LH1656  47.1026  17.91910  10210.0  109.0
# 2  EMBRAER   495  300738  DLH2382  LH2382  47.4266   8.22242   9136.0  247.0
# 3  EMBRAER  1086  300738  DLH2383  LH2383  47.8228  10.93930   4030.0   70.0
# 4  EMBRAER  1213  300738   DLH4XY   LH4XY  45.5245   9.07497   2903.0  216.0
#
#       36   37          38              39   40    41  \
# 0  837.0 -1.0  2022-08-16 0 days 15:36:00  MUC  EDDM
# 1  837.0 -1.0  2022-08-16 0 days 15:51:00  MUC  EDDM
# 2  681.0 -1.0  2022-08-17 0 days 09:08:00  MUC  EDDM
# 3  635.0 -1.0  2022-08-17 0 days 10:52:00  MUC  EDDM
# 4  516.0 -1.0  2022-09-07 0 days 16:49:00  MUC  EDDM
#
#                              42  43     44     45   46    47  \
# 0  Munich International Airport  DE  48.35  11.79  TSR  LRTR
# 1  Munich International Airport  DE  48.35  11.79  TSR  LRTR
# 2  Munich International Airport  DE  48.35  11.79  TSR  LRTR
# 3  Munich International Airport  DE  48.35  11.79  TSR  LRTR
# 4  Munich International Airport  DE  48.35  11.79  TSR  LRTR
#
#                                             48  49     50     51  52   53  \
# 0  Timisoara Traian Vuia International Airport  RO  45.81  21.33  DE  DEU
# 1  Timisoara Traian Vuia International Airport  RO  45.81  21.33  DE  DEU
# 2  Timisoara Traian Vuia International Airport  RO  45.81  21.33  DE  DEU
# 3  Timisoara Traian Vuia International Airport  RO  45.81  21.33  DE  DEU
# 4  Timisoara Traian Vuia International Airport  RO  45.81  21.33  DE  DEU
#
#         54  55   56       57
# 0  Germany  RO  ROU  Romania
# 1  Germany  RO  ROU  Romania
# 2  Germany  RO  ROU  Romania
# 3  Germany  RO  ROU  Romania
# 4  Germany  RO  ROU  Romania

# %%
# A LANCER A CHAQUE FIN DE SESSION:

cursor.close()
cnx.close()
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# /home/ad/main/datascientest/dst-airlines/DST-airlines/src/dst_sql/sql_queries_rds.ipynb Cell 5 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/home/ad/main/datascientest/dst-airlines/DST-airlines/src/dst_sql/sql_queries_rds.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> # A LANCER A CHAQUE FIN DE SESSION:
#       <a href='vscode-notebook-cell:/home/ad/main/datascientest/dst-airlines/DST-airlines/src/dst_sql/sql_queries_rds.ipynb#W4sZmlsZQ%3D%3D?line=2'>3</a> cursor.close()
# ----> <a href='vscode-notebook-cell:/home/ad/main/datascientest/dst-airlines/DST-airlines/src/dst_sql/sql_queries_rds.ipynb#W4sZmlsZQ%3D%3D?line=3'>4</a> cnx.close()
#
# File ~/.local/lib/python3.10/site-packages/pymysql/connections.py:404, in Connection.close(self)
#     395 """
#     396 Send the quit message and close the socket.
#     397
#    (...)
#     401 :raise Error: If the connection is already closed.
#     402 """
#     403 if self._closed:
# --> 404     raise err.Error("Already closed")
#     405 self._closed = True
#     406 if self._sock is None:
#
# Error: Already closed
